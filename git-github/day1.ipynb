# %%
# git-- distributed version control system
# git hub--- storage for git repositories,,you can store your code,keep track of changes in your code using git
# it will also allow you to collaborate with other developers on the same project

# %%
# echo "# git-github-batch14" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/sunilmainali/git-github-batch14.git
# git push -u origin main

# %%
###
# working file--->git add <file name>--->staging area--->git commit--->local repository--->git push--->remote repository
